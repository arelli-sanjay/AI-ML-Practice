# %% [markdown]
# # Data Initialization

# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_excel('Book2.xlsx')

# %%
dataset.head(10)
# Out:
#    years of experience  Salary
# 0                 1.10   39343
# 1                 1.30   46202
# 2                 1.50   37731
# 3                 2.00   43525
# 4                 2.20   38891
# 5                 2.90   56642
# 6                 3.00   60150
# 7                 3.32   54445
# 8                 3.20   64445
# 9                 3.70   57189

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   years of experience  29 non-null     float64
#  1   Salary               29 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 596.0 bytes

# %%
x = dataset.iloc[:,:-1].values

# %%
y = dataset.iloc[:,-1].values

# %%
y
# Out:
# array([ 39343,  46202,  37731,  43525,  38891,  56642,  60150,  54445,
#         64445,  57189,  63218,  55791,  56957,  57081,  61111,  67928,
#         66029,  83088,  81363,  93940,  91739,  98273, 101302, 113821,
#        109431, 105582, 112635, 122391, 121872])

# %% [markdown]
# # Data Spliting

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 1/3,random_state = 10)

# %% [markdown]
# # Creating Our Model

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Predict

# %%
x_test
# Out:
# array([[4.5 ],
#        [3.32],
#        [2.9 ],
#        [1.5 ],
#        [9.6 ],
#        [6.8 ],
#        [4.  ],
#        [4.1 ],
#        [5.9 ],
#        [1.3 ]])

# %%
y_pred = reg.predict(x_test)

# %%
y_pred
# Out:
# array([ 68479.92685207,  57578.72595223,  53698.63749635,  40765.0093101 ,
#        115595.28667343,  89728.03030092,  63860.77392841,  64784.60451314,
#         81413.55503833,  38917.34814063])

# %%
y_test
# Out:
# array([ 61111,  54445,  56642,  37731, 112635,  91739,  56957,  57081,
#         81363,  46202])

# %% [markdown]
# # Visualising Training Set

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x_train,y_train,color = 'red')
plt.plot(x_train,reg.predict(x_train),color = 'blue')

# %%
plt.scatter(x_train,y_train,color = 'red')
plt.plot(x_test,reg.predict(x_test), color = 'blue')
